# %% [markdown]
# # Data Analysis Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# from matplotlib_venn import venn2
import pydst # Danmarks Statistik

# %%
Dst = pydst.Dst(lang='en') # Set language to English

# %%
Dst.get_subjects() # Get overview of Statistics Denmark's subjects
# Out:
#     active                                       desc  hasSubjects  id
# 0     True                   Population and elections         True  02
# 1     True                          Living conditions         True  05
# 2     True                    Education and knowledge         True  03
# 3     True                Culture and National Church         True  18
# 4     True                  Labour, income and wealth         True  04
# 5     True                     Prices and consumption         True  06
# 6     True  National accounts and government finances         True  14
# 7     True                    Money and credit market         True  16
# 8     True                           External economy         True  13
# 9     True                 Business sector in general         True  07
# 10    True                           Business sectors         True  11
# 11    True          Geography, environment and energy         True  01
# 12    True                                      Other         True  19

# %%
Dst.get_data(table_id = 'BB1S')
# Out:
#           POST          INDUDBOP                    SÆSON               LAND  \
# 0  GOODS (FOB)  Current receipts  Non-seasonally adjusted  REST OF THE WORLD
#
#        TID  INDHOLD
# 0  2005M01     34.8

# %%
Var = Dst.get_variables(table_id = 'BB1S')

# %%
Var[:]
# Out:
#    elimination        id                  text   time  \
# 0         True      POST                 items  False
# 1        False  INDUDBOP  receipts/expenditure  False
# 2        False     SÆSON   seasonal adjustment  False
# 3         True      LAND               country  False
# 4        False       Tid                  time   True
#
#                                               values
# 0  [{'id': '1.A.A', 'text': 'GOODS (FOB)'}, {'id'...
# 1  [{'id': 'K', 'text': 'Current receipts'}, {'id...
# 2  [{'id': '1', 'text': 'Non-seasonally adjusted'...
# 3  [{'id': 'W1', 'text': 'REST OF THE WORLD'}, {'...
# 4  [{'id': '2005M01', 'text': '2005M01'}, {'id': ...

# %%
Var['values'][4][:10]
# Out:
# [{'id': '2005M01', 'text': '2005M01'},
#  {'id': '2005M02', 'text': '2005M02'},
#  {'id': '2005M03', 'text': '2005M03'},
#  {'id': '2005M04', 'text': '2005M04'},
#  {'id': '2005M05', 'text': '2005M05'},
#  {'id': '2005M06', 'text': '2005M06'},
#  {'id': '2005M07', 'text': '2005M07'},
#  {'id': '2005M08', 'text': '2005M08'},
#  {'id': '2005M09', 'text': '2005M09'},
#  {'id': '2005M10', 'text': '2005M10'}]

# %%
Dst.get_data(table_id = 'BB1S', variables={'TID':['*'], 'SÆSON':['2'], 'LAND':['W1'], 'POST':['*'], 'INDUDBOP':['N']})
# Out:
#          TID                SÆSON               LAND              POST  \
# 0    2007M05  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 1    2007M05  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 2    2007M06  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 3    2007M06  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 4    2007M06  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 5    2007M06  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 6    2007M06  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 7    2007M07  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 8    2007M07  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 9    2007M07  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 10   2007M07  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 11   2007M07  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 12   2007M08  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 13   2007M08  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 14   2007M08  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 15   2007M08  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 16   2007M08  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 17   2007M09  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 18   2007M09  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 19   2007M09  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 20   2007M09  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 21   2007M09  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 22   2007M10  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 23   2007M10  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 24   2007M10  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 25   2007M10  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 26   2007M10  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 27   2007M11  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 28   2007M11  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 29   2007M11  Seasonally adjusted  REST OF THE WORLD          SERVICES
# ..       ...                  ...                ...               ...
# 815  2014M08  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 816  2014M08  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 817  2014M08  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 818  2014M08  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 819  2014M09  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 820  2014M09  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 821  2014M09  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 822  2014M09  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 823  2014M09  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 824  2014M10  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 825  2014M10  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 826  2014M10  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 827  2014M10  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 828  2014M10  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 829  2014M11  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 830  2014M11  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 831  2014M11  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 832  2014M11  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 833  2014M11  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 834  2014M12  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 835  2014M12  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 836  2014M12  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 837  2014M12  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 838  2014M12  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 839  2015M01  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
# 840  2015M01  Seasonally adjusted  REST OF THE WORLD       GOODS (FOB)
# 841  2015M01  Seasonally adjusted  REST OF THE WORLD          SERVICES
# 842  2015M01  Seasonally adjusted  REST OF THE WORLD    PRIMARY INCOME
# 843  2015M01  Seasonally adjusted  REST OF THE WORLD  SECONDARY INCOME
# 844  2015M02  Seasonally adjusted  REST OF THE WORLD   CURRENT ACCOUNT
#
#          INDUDBOP  INDHOLD
# 0    Net receipts      0.8
# 1    Net receipts     -3.0
# 2    Net receipts      2.5
# 3    Net receipts      2.5
# 4    Net receipts      2.6
# 5    Net receipts      0.3
# 6    Net receipts     -2.9
# 7    Net receipts      2.7
# 8    Net receipts      1.8
# 9    Net receipts      3.2
# 10   Net receipts      0.8
# 11   Net receipts     -3.1
# 12   Net receipts      1.6
# 13   Net receipts      0.8
# 14   Net receipts      3.2
# 15   Net receipts      0.7
# 16   Net receipts     -3.1
# 17   Net receipts      2.1
# 18   Net receipts      1.7
# 19   Net receipts      3.3
# 20   Net receipts      0.3
# 21   Net receipts     -3.2
# 22   Net receipts      2.9
# 23   Net receipts      0.6
# 24   Net receipts      3.5
# 25   Net receipts      1.1
# 26   Net receipts     -2.3
# 27   Net receipts      3.7
# 28   Net receipts      2.2
# 29   Net receipts      2.9
# ..            ...      ...
# 815  Net receipts      9.3
# 816  Net receipts      4.7
# 817  Net receipts      6.5
# 818  Net receipts     -2.3
# 819  Net receipts     14.0
# 820  Net receipts      6.3
# 821  Net receipts      4.5
# 822  Net receipts      5.8
# 823  Net receipts     -2.5
# 824  Net receipts     14.9
# 825  Net receipts      7.4
# 826  Net receipts      3.5
# 827  Net receipts      6.6
# 828  Net receipts     -2.6
# 829  Net receipts     17.3
# 830  Net receipts      8.5
# 831  Net receipts      5.0
# 832  Net receipts      6.4
# 833  Net receipts     -2.5
# 834  Net receipts     18.1
# 835  Net receipts     10.4
# 836  Net receipts      4.1
# 837  Net receipts      6.0
# 838  Net receipts     -2.3
# 839  Net receipts     14.0
# 840  Net receipts      6.6
# 841  Net receipts      4.8
# 842  Net receipts      6.1
# 843  Net receipts     -3.4
# 844  Net receipts     17.2
#
# [845 rows x 6 columns]

# %%
df = Dst.get_data(table_id = 'BB1S', variables={'Tid':['*'], 'SÆSON':['2'], 'LAND':['W1'], 'POST':['*'], 'INDUDBOP':['N']})

# %%
PI  = df.loc[df['POST'] == 'PRIMARY INCOME', :]
tid = df.loc[df['POST'] == 'PRIMARY INCOME', :]

# %%
PI['INDHOLD']
# Out:
# 0      0.8
# 5      0.3
# 10     0.8
# 15     0.7
# 20     0.3
# 25     1.1
# 30     0.8
# 35     1.1
# 40     1.2
# 45     0.7
# 50     0.7
# 55     2.4
# 60     1.8
# 65     1.1
# 70     1.5
# 75     2.4
# 80     2.8
# 85     2.4
# 90     2.8
# 95    -0.2
# 100    1.2
# 105    0.4
# 110    2.6
# 115    2.8
# 120    1.5
# 125    1.1
# 130    1.4
# 135    0.8
# 140    1.3
# 145    1.5
#       ...
# 696    3.7
# 701    4.3
# 707    5.2
# 712    4.9
# 717    5.0
# 722    4.7
# 730    3.9
# 735    4.0
# 740    4.4
# 745    3.6
# 747    5.2
# 752    5.2
# 757    5.8
# 762    5.0
# 767    4.9
# 772    4.3
# 777    5.3
# 782    6.3
# 787    6.6
# 792    4.0
# 797    6.2
# 802    5.2
# 807    5.2
# 812    8.3
# 817    6.5
# 822    5.8
# 827    6.6
# 832    6.4
# 837    6.0
# 842    6.1
# Name: INDHOLD, Length: 169, dtype: float64

# %%
fig, ax = plt.subplots()

ax.plot(PI['TID'],PI['INDHOLD'])

plt.show()
